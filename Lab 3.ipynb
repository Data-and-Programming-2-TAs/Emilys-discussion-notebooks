# %% [markdown]
# ## Lab 3: Natural Language Processing

# %% [markdown]
# - Spacy documentation: https://spacy.io/usage/spacy-101
# - Another library is NLTK (we don't cover in this class): https://www.nltk.org/

# %%
import pandas as pd
import spacy #conda install spacy
             #python -m spacy download en_core_web_sm
             #pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz

# %%
# Source: https://www.nytimes.com/live/2020/10/14/world/covid-coronavirus
text = """Sixteen states each added more not new cases in the seven-day period ending Monday than they had in any \
other weeklong stretch of the pandemic. North Dakota and South Dakota are reporting more new cases per person \
than any state has previously. And in Wisconsin, home to 10 of the country’s 20 metro areas with the highest \
rates of recent cases, crews are preparing a field hospital at the state fairgrounds."""

# Parse text through the `nlp` model
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# %% [markdown]
# ### Sentences

# %%
sents = list(doc.sents)
for i, sent in enumerate(sents):
    print(i+1, sent)
# Out:
# 1 Sixteen states each added more not new cases in the seven-day period ending Monday than they had in any other weeklong stretch of the pandemic.
# 2 North Dakota and South Dakota are reporting more new cases per person than any state has previously.
# 3 And in Wisconsin, home to 10 of the country’s 20 metro areas with the highest rates of recent cases, crews are preparing a field hospital at the state fairgrounds.

# %% [markdown]
# ### Tokens
# i.e. a word, punctuation symbol, whitespace, etc.

# %%
print ([token.text for token in sents[0]])
# Out:
# ['Sixteen', 'states', 'each', 'added', 'more', 'not', 'new', 'cases', 'in', 'the', 'seven', '-', 'day', 'period', 'ending', 'Monday', 'than', 'they', 'had', 'in', 'any', 'other', 'weeklong', 'stretch', 'of', 'the', 'pandemic', '.']

# %% [markdown]
# Lemmatization is the method of converting a token to it’s root/base form.
#
# For example: 'played' and 'playing' have the same root: 'play'.

# %%
word = doc[5]

print('Original word: {}'.format(doc[3]))

print('Lemmatized word: {}'.format(word.lemma_))

# Attributes of a word
print('\nWord: {} \nPart of speech: {} \nAll alphabet letters? {}\nIs punctuation? {}\nIs stop word? {}\nDependency: {}'\
      .format(word.text, word.pos_, word.is_alpha, word.is_punct, word.is_stop, word.dep_))
# Out:
# Original word: added
# Lemmatized word: not
#
# Word: not
# Part of speech: PART
# All alphabet letters? True
# Is punctuation? False
# Is stop word? True
# Dependency: neg

# %% [markdown]
# ### Entities

# %%
entities = [(entity.label_, entity.text) for entity in doc.ents]
print(entities)
# Out:
# [('CARDINAL', 'Sixteen'), ('DATE', 'seven-day'), ('DATE', 'Monday'), ('GPE', 'North Dakota'), ('GPE', 'South Dakota'), ('GPE', 'Wisconsin'), ('CARDINAL', '10'), ('QUANTITY', '20 metro')]

# %% [markdown]
# ### Cleaning data
# One common step in data cleaning is getting rid of stop words. Stop words are words in the English language that don't necessarily add a lot in terms of meaning - e.g., 'and', 'or', 'by', etc. Spacy and NLTK have build in lists of stop words.

# %%
word.is_stop
# Out:
# False

# %%
# Removing stop words & punctuation
clean_tokens = [t for t in doc if (t.is_stop == False) and (t.is_punct == False)]
print(clean_tokens)
# Out:
# [Sixteen, states, added, new, cases, seven, day, period, ending, Monday, weeklong, stretch, pandemic, North, Dakota, South, Dakota, reporting, new, cases, person, state, previously, Wisconsin, home, 10, country, 20, metro, areas, highest, rates, recent, cases, crews, preparing, field, hospital, state, fairgrounds]

# %% [markdown]
# ## Preprocessing: Amazon Example
# Download dataset from here: https://www.kaggle.com/sid321axn/amazon-alexa-reviews

# %%
df_amazon = pd.read_csv("Data/amazon_alexa.tsv", sep="\t")
df_amazon.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
# example from: https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/

import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

nlp = spacy.load("en_core_web_sm")
stop_words = spacy.lang.en.stop_words.STOP_WORDS
parser = English()
punctuations = string.punctuation

def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = parser(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens
# Out:
# /Users/ezhang/anaconda3/lib/python3.7/site-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.2). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
tokens = {}
for i in range(len(df_amazon)):
    tokens[i] = spacy_tokenizer(df_amazon.verified_reviews[i])

# %%
tokens
# Out:
# {0: ['love', 'echo'],
#  1: ['loved'],
#  2: ['playing',
#   'game',
#   'answer',
#   'question',
#   'correctly',
#   'alexa',
#   'says',
#   'got',
#   'wrong',
#   'answers',
#   'like',
#   'able',
#   'turn',
#   'lights',
#   'away',
#   'home'],
#  3: ['lot',
#   'fun',
#   'thing',
#   '4',
#   'yr',
#   'old',
#   'learns',
#   'dinosaurs',
#   'control',
#   'lights',
#   'play',
#   'games',
#   'like',
#   'categories',
#   'nice',
#   'sound',
#   'playing',
#   'music'],
#  4: ['music'],
#  5: ['received',
#   'echo',
#   'gift',
#   'needed',
#   'bluetooth',
#   'play',
#   'music',
#   'easily',
#   'accessible',
#   'found',
#   'smart',
#   'speaker',
#   'wait'],
#  6: ['having',
#   'cellphone',
#   'use',
#   'features',
#   'ipad',
#   'use',
#   'great',
#   'alarm',
#   'u',
#   'r',
#   'deaf',
#   'hear',
#   'alarm',
#   'bedroom',
#   'living',
#   'room',
#   'reason',
#   'fun',
#   'ask',
#   'random',
#   'questions',
#   'hear',
#   'response',
#   'smartbon',
#   'politics'],
#  7: ['think',
#   '5th',
#   'purchased',
#   'working',
#   'getting',
#   'room',
#   'house',
#   'like',
#   'features',
#   'offer',
#   'specifily',
#   'playing',
#   'music',
#   'echos',
#   'controlling',
#   'lights',
#   'house'],
#  8: ['looks', 'great'],
#  9: ['love',
#   'listened',
#   'songs',
#   'heard',
#   'childhood',
#   'news',
#   'weather',
#   'information',
#   'great'],
#  10: ['sent', '85', 'year', 'old', 'dad', 'talks', 'constantly'],
#  11: ['love',
#   'learning',
#   'knew',
#   'things',
#   'eveyday',
#   'figuring',
#   'works',
#   'far',
#   'easy',
#   'use',
#   'understand',
#   'laugh',
#   'times'],
#  12: ['purchased',
#   'mother',
#   'having',
#   'knee',
#   'problems',
#   'trying',
#   'come',
#   'getting',
#   'fast',
#   'like',
#   'enjoys',
#   'little',
#   'big',
#   'things',
#   '...',
#   'alexa',
#   'play',
#   'song',
#   'time',
#   'cook'],
#  13: ['love', 'love', 'love'],
#  14: ['expected', '....'],
#  15: ['love', 'wife', 'hates'],
#  16: ['happy', 'purchase', 'great', 'speaker', 'easy', 'set'],
#  17: ['alexa',
#   'couple',
#   'days',
#   'having',
#   'lot',
#   'fun',
#   'new',
#   'toy',
#   'like',
#   'having',
#   'new',
#   'household',
#   'member',
#   'trying',
#   'learn',
#   'different',
#   'featues',
#   'benefits',
#   'come'],
#  18: ['love',
#   'size',
#   '2nd',
#   'generation',
#   'echo',
#   'needs',
#   'little',
#   'improvement',
#   'sound'],
#  19: ['liked',
#   'original',
#   'echo',
#   'shorter',
#   'greater',
#   'fabric',
#   'color',
#   'choices',
#   'miss',
#   'volume',
#   'ring',
#   'plus',
#   'minus',
#   'buttons',
#   'big',
#   'deal',
#   'ring',
#   'w',
#   'comforting',
#   ':)',
#   'like',
#   'use',
#   'standard',
#   'usb',
#   'charger',
#   '/port',
#   'instead',
#   'previous',
#   'round',
#   'pin',
#   'guess',
#   'sounds',
#   'work',
#   'answers',
#   'alexa',
#   'echo',
#   'computer',
#   'like',
#   ':)'],
#  20: ['love',
#   'echo',
#   'good',
#   'music',
#   'sounds',
#   'playing',
#   'alexa',
#   'understands',
#   'commands',
#   'difficult',
#   'times',
#   'find',
#   'specific',
#   'playlists',
#   'songs',
#   'spotify',
#   'good',
#   'amazon',
#   'music',
#   'lacking',
#   'major',
#   'programs'],
#  21: ['love',
#   'alexa',
#   'use',
#   'play',
#   'music',
#   'play',
#   'radio',
#   'itunes',
#   'play',
#   'podcasts',
#   'anypod',
#   'set',
#   'reminders',
#   'listen',
#   'flash',
#   'briefing',
#   'news',
#   'weather',
#   'morning',
#   'rely',
#   'custom',
#   'lists',
#   'like',
#   'able',
#   'voice',
#   'control',
#   'volume',
#   'sure',
#   'continue',
#   'find',
#   'new',
#   'uses',
#   'bit',
#   'frustrating',
#   'alexa',
#   'understand',
#   'saying'],
#  22: ['set',
#   'days',
#   'adding',
#   'smart',
#   'home',
#   'devices',
#   'speaker',
#   'great',
#   'playing',
#   'music',
#   'like',
#   'size',
#   'stationed',
#   'kitchen',
#   'counter',
#   'intrusive',
#   'look'],
#  23: ['love', 'plays', 'sleep', 'sounds', 'immediately', 'ask'],
#  24: ['got',
#   'second',
#   'unit',
#   'bedroom',
#   'expecting',
#   'sounds',
#   'improved',
#   'difference',
#   'overall',
#   'big',
#   'improvement',
#   '1st',
#   'generation'],
#  25: ['amazing', 'product'],
#  26: ['love',
#   'echo',
#   'easy',
#   'operate',
#   'loads',
#   'fun',
#   'advertised',
#   'use',
#   'mainly',
#   'play',
#   'favorite',
#   'tunes',
#   'test',
#   'alexa',
#   'knowledge'],
#  27: ['sounds', 'great', 'love'],
#  28: ['fun',
#   'item',
#   'play',
#   'hard',
#   'time',
#   'answering',
#   'questions',
#   'ask',
#   'think',
#   'better'],
#  29: ['like'],
#  30: ['learning',
#   'capabilities',
#   '...',
#   'far',
#   'pretty',
#   'pretty',
#   'pretty',
#   'good'],
#  31: ['like'],
#  32: ['works',
#   'needs',
#   'learning',
#   'command',
#   'unique',
#   'owners',
#   'users',
#   'like',
#   'alexa',
#   '“',
#   'learn',
#   '”',
#   'tasha',
#   'birthday',
#   'alexa',
#   '“',
#   'learn',
#   '”',
#   'definition',
#   'fine',
#   'etc',
#   'great'],
#  33: ['speakers',
#   'sound',
#   'pretty',
#   'good',
#   'small',
#   'setup',
#   'pretty',
#   'easy',
#   'bought',
#   'reason',
#   'rate',
#   '3',
#   'followed',
#   'instructions',
#   'synching',
#   'music',
#   'units',
#   'know',
#   'correctly',
#   'sync',
#   'primary',
#   'motivation',
#   'purchasing',
#   'multiple',
#   'units'],
#  34: ['device', 'awesome'],
#  35: ['bought',
#   'compare',
#   'speaker',
#   'quality',
#   'generation',
#   'speaker',
#   'like',
#   'sound',
#   'better',
#   'ship',
#   'daughter',
#   'like',
#   'fact',
#   'generation',
#   'chargeable',
#   'base',
#   'bought',
#   'keeps',
#   'mobile',
#   'needs',
#   'better',
#   'sound'],
#  36: ['love',
#   'echo',
#   'learning',
#   'things',
#   'able',
#   'follow',
#   'instructions',
#   'included',
#   'package',
#   'found',
#   'great',
#   'u',
#   'tube'],
#  37: ['speaker', 'better', '1st', 'generation', 'echo'],
#  38: ['thing', 'way', 'cool', 'want', 'cool'],
#  39: ['digital',
#   'assistant',
#   'giving',
#   'good',
#   'review',
#   'speaker',
#   'good',
#   'cheap',
#   'price',
#   'prime',
#   'day',
#   'fun',
#   'play',
#   'alarm',
#   'clock',
#   'going',
#   'place',
#   'ended',
#   'echo',
#   'definitely',
#   'try',
#   'it!what',
#   'like',
#   'best',
#   'number',
#   'devices',
#   'connect',
#   'purchase',
#   'came',
#   'smart',
#   'plug',
#   '10',
#   'connect',
#   'lamp',
#   'alexa',
#   'turn',
#   'lights'],
#  40: ['husband',
#   'likes',
#   'able',
#   'use',
#   'listen',
#   'music',
#   'wish',
#   'knew',
#   'capabilities'],
#  41: ['android',
#   'allow',
#   'alexa',
#   'connect',
#   'fortunately',
#   'sister',
#   'apple',
#   'cell',
#   'hour+',
#   'tech',
#   'support',
#   'fixed',
#   'glitches',
#   'running'],
#  42: ['far', 'good'],
#  43: ['tried',
#   'play',
#   'certain',
#   'broadway',
#   'shows',
#   'like',
#   'camelot',
#   'gives',
#   'ne',
#   'group',
#   'camelot'],
#  44: ['great'],
#  45: ['satisfied',
#   'echo',
#   'alexa',
#   'controls',
#   'lights',
#   'family',
#   'room',
#   'wife',
#   'listen',
#   'jimmy',
#   'buffet',
#   'asking',
#   'alexa'],
#  46: ['like',
#   'siri',
#   'fact',
#   'siri',
#   'answers',
#   'accurately',
#   'alexa',
#   'real',
#   'need',
#   'household',
#   'good',
#   'bargain',
#   'prime',
#   'day',
#   'deals'],
#  47: ['love', 'echo', 'learning', 'thing', 'works', 'having', 'tons', 'fun'],
#  48: ['love'],
#  49: ['different',
#   'apple',
#   'play',
#   'specific',
#   'list',
#   'music',
#   'amazon',
#   'spotify',
#   '“',
#   'plus',
#   'prime',
#   'etc',
#   '”',
#   'account',
#   'pay',
#   'play',
#   '“',
#   '”',
#   'music',
#   '3',
#   'stars',
#   'reason',
#   '👍',
#   '🏻'],
#  50: ['excelente', 'lo', 'unico', 'es', 'que', 'esta', 'en', 'español'],
#  51: ['learning',
#   'use',
#   'far',
#   'echo',
#   'great',
#   'sound',
#   'actually',
#   'better',
#   'expecting'],
#  52: ['works',
#   'expect',
#   'good',
#   'sound',
#   'quality',
#   'considering',
#   'price',
#   '70.00',
#   'sale',
#   'features'],
#  53: ['sound',
#   'echo',
#   '2nd',
#   'generation',
#   'phenomenal',
#   'mention',
#   'love',
#   'alexa',
#   'helpful'],
#  54: ['like', 'google', 'better'],
#  55: ['lets', 'play', 'learn'],
#  56: ['works', 'advertised', 'easy', 'setup', 'learning'],
#  57: ['great', 'sound', 'easy', 'set'],
#  58: ['love', 'alexa', 'bought', 'friends'],
#  59: ['love',
#   'echo',
#   'purchased',
#   'company',
#   'husband',
#   '83',
#   'alexa',
#   'great',
#   'tells',
#   'joke',
#   'plays',
#   'favorite',
#   'songs'],
#  60: ['😍'],
#  61: ['love',
#   'able',
#   'listen',
#   'music',
#   'easily',
#   'learning',
#   'features',
#   'available'],
#  62: ['t', 'know', 'use', 'device', 'things', 'need', 'overview'],
#  63: ['love', 'wish', 'built', 'hub'],
#  64: ['use',
#   'primarily',
#   'play',
#   'music',
#   'works',
#   'wonderfully',
#   'getting',
#   'things',
#   'amazon',
#   'sent',
#   'tips',
#   'got',
#   'thanks',
#   'help'],
#  65: ['easy', 'set'],
#  66: ['fast',
#   'response',
#   'amazing',
#   'clear',
#   'concise',
#   'answers',
#   'sound',
#   'quality',
#   'fantastic',
#   'getting',
#   'alexia',
#   'usde',
#   'echo',
#   'extent'],
#  67: ['need', '...', 'na', 'na', 'nana'],
#  68: ['expected'],
#  69: ['love',
#   'echo',
#   'works',
#   'like',
#   'said',
#   '34;smart&#34',
#   'home',
#   'speak',
#   'function',
#   'good'],
#  70: ['great', 'sound', 'small', 'package', '—', 'easy', 'set', 'use', 'fun'],
#  71: ['works', 'sounds', 'great'],
#  72: ['sound', 'amazing', 'collections', 'music'],
#  73: ['setting'],
#  74: ['listen'],
#  75: ['awesome'],
#  76: ['bought',
#   'control',
#   'fios',
#   'television',
#   'works',
#   'hoping',
#   'time',
#   'control',
#   'fios',
#   'discovered',
#   'things',
#   'alexa',
#   'play',
#   'music',
#   'ask',
#   'great',
#   'sound',
#   'alexa',
#   'play',
#   'games',
#   'play',
#   'radio',
#   'stations',
#   'play',
#   'old',
#   'time',
#   'radio',
#   'programs',
#   'like',
#   'long',
#   'ranger',
#   'alexa',
#   '“',
#   'apps',
#   '”',
#   'add',
#   'abilities',
#   'day',
#   'played',
#   'madlibs',
#   'great',
#   'fun',
#   'alexa',
#   'control',
#   'household',
#   'appliances',
#   'purchased',
#   'alexa',
#   'compatible',
#   'power',
#   'strips',
#   'control',
#   'lighting',
#   'fans',
#   'tv',
#   'components',
#   'looking',
#   'forward',
#   'implementing',
#   'controll',
#   'add',
#   'alexa',
#   'components',
#   'chosen',
#   'music',
#   'play',
#   'rooms',
#   'components',
#   'located'],
#  77: ['speaker', 'excellent', 'sound', 'works', 'perfectly'],
#  78: ['like'],
#  79: ['love'],
#  80: ['little',
#   'nervous',
#   'received',
#   'new',
#   'echo',
#   'tech',
#   'savvy',
#   'found',
#   'bit',
#   'intimidating',
#   'long',
#   'figure',
#   'happy',
#   'purchase',
#   'thinking',
#   'adding',
#   'echo',
#   'spot'],
#  81: ['like', 'learning', 'use'],
#  82: ['great',
#   'technology',
#   'believe',
#   'speaker',
#   'volume',
#   'quality',
#   'wonderful',
#   'wish',
#   'bought'],
#  83: ['purchased',
#   'echo',
#   'dot',
#   'husband',
#   'fathers',
#   'day',
#   'uses',
#   'constantly',
#   'hearing',
#   'quality',
#   'sound',
#   'echo',
#   '2nd',
#   'generation',
#   'brainer',
#   'best',
#   'gift'],
#  84: ['works', 'fine'],
#  85: [],
#  86: ['clear', 'music'],
#  87: ['fun', 'use', 'good', 'sound', 'quality'],
#  88: ['echo', 'works', 'able', 'sync', 'amazon', 'music', 'devices'],
#  89: ['works',
#   'great',
#   'think',
#   'amazon',
#   'charge',
#   'cent',
#   'unlimited',
#   'music',
#   '1',
#   'prime',
#   '2',
#   'buy',
#   'echo'],
#  90: ['echo',
#   'dot',
#   'echo',
#   'better',
#   'fuller',
#   'sound',
#   'setup',
#   'lets',
#   'phone',
#   'calls',
#   'contact',
#   'list',
#   'great'],
#  91: ['speaker', 'sounds', 'good'],
#  92: ['good', 'sound', 'works'],
#  93: ['love', 'alexa', 'savvy', 'support', 'helpful', 'patient'],
#  94: ['love',
#   'thinking',
#   'getting',
#   'prime',
#   'day',
#   'discount',
#   'offered',
#   'pass',
#   'fun',
#   'ask',
#   'alexa',
#   'play',
#   'song',
#   'group',
#   'comes',
#   'playlist',
#   'amazon',
#   'prime',
#   'music',
#   'connect',
#   'iphone',
#   'bluetooth',
#   'play',
#   'music',
#   'pandora',
#   'youtube',
#   'videos',
#   'alexa',
#   'speaker',
#   'having',
#   'fun',
#   'asking',
#   'alexa',
#   'different',
#   'types',
#   'questions',
#   'information',
#   'like',
#   'weather',
#   'news',
#   'time',
#   'countries',
#   'downside',
#   'limited',
#   'data',
#   'wifi',
#   'plan',
#   'alexa',
#   'uses',
#   'burns',
#   'playing',
#   'music'],
#  95: ['like', 'far', 'lot', 'try'],
#  96: ['love', 'strictly', 'music', 'great'],
#  97: ['love',
#   'echo',
#   'love',
#   'size',
#   'material',
#   'speaker',
#   'quality',
#   'hooked',
#   'light',
#   'easily',
#   'work',
#   'additional',
#   'lights',
#   'thermostat',
#   'echo',
#   'dot',
#   'bedroom',
#   'lot',
#   'echo',
#   'think',
#   'traffic',
#   'weather',
#   'trivia',
#   'etc'],
#  98: ['love'],
#  99: ['entire', 'family', 'loves', 'alexa', 'echo', 'family'],
#  100: ['great',
#   'fun',
#   'getting',
#   'know',
#   'functions',
#   'product',
#   'wow',
#   '--',
#   'family',
#   'fun',
#   'homework',
#   'help',
#   'talking',
#   'grandchildren',
#   'echo',
#   'huge',
#   'bonus',
#   'wait',
#   'learn'],
#  101: ['love'],
#  102: ['awesome', 'thing', 'love', 'alexa'],
#  103: ['worked',
#   'exactly',
#   'expected',
#   'speaker',
#   'great',
#   'sound',
#   'perfect',
#   'classroom'],
#  104: ['love',
#   'love',
#   'new',
#   'little',
#   'gadget',
#   'lives',
#   'easier',
#   'like',
#   'having',
#   'personal',
#   'secretary',
#   'living',
#   'home',
#   'hardly',
#   'need',
#   'cd',
#   'anymore',
#   'alexa',
#   'plays',
#   'need',
#   'going',
#   'alexa',
#   'dots',
#   'soon',
#   'rooms',
#   'thanks'],
#  105: ['speaker', 'surprising', 'quality', 'happy', 'purchase'],
#  106: ['easy', 'set', 'works', 'wonderful', 'love'],
#  107: ['impressed',
#   'sound',
#   'quality',
#   'playing',
#   'music',
#   'device',
#   'bass',
#   'sounds',
#   'like',
#   'coming',
#   'bigger',
#   'speaker',
#   'props',
#   'amazon'],
#  108: ['great',
#   'product',
#   'sound',
#   'quality',
#   'worse',
#   'don’t',
#   'wrong',
#   'definitely',
#   'hour',
#   'definitely',
#   'feels',
#   'like',
#   'echo',
#   'gen',
#   '1',
#   'sound',
#   'quality',
#   'better',
#   'great',
#   'addition',
#   'able',
#   'play',
#   'bluetooth',
#   'wifi',
#   'better'],
#  109: ['outlet', 'work', 'disappointed'],
#  110: ['great', 'device', 'responsive', 'helpful'],
#  111: ['sound', 'terrible', 'u', 'want', 'good', 'music', 'bose'],
#  112: ['liked',
#   'sound',
#   'troubling',
#   'paid',
#   'extra',
#   'money',
#   'access',
#   'million',
#   'songs',
#   'work',
#   'ex',
#   'alexa',
#   'play',
#   'italian',
#   'songs&#34',
#   ".don't",
#   'don&#34',
#   't',
#   'understand',
#   'play',
#   'opera',
#   'tosca',
#   'response',
#   '34;sorry',
#   'don&#34;t'],
#  113: ['easy',
#   'set',
#   'use',
#   'bad',
#   'plugged',
#   'nice',
#   'outside',
#   'operate',
#   'battery',
#   'recharged'],
#  114: ['learning',
#   'ways',
#   'use',
#   'real',
#   'hit',
#   'grandkids',
#   'ask',
#   'play',
#   'music',
#   'dance',
#   '5',
#   '7',
#   'yrs',
#   'cute'],
#  115: ['4.5',
#   '5',
#   'stars',
#   'generally',
#   'like',
#   'product',
#   'great',
#   'ask',
#   'like',
#   'playing',
#   'music',
#   'setting',
#   'timers',
#   'making',
#   'calls',
#   'reason',
#   'rate',
#   '5',
#   '5',
#   'connection',
#   'dies',
#   'echo',
#   'stops',
#   'playing',
#   'music',
#   'shows',
#   'red',
#   'ring',
#   'connection',
#   'issue',
#   'overall',
#   'great',
#   'product'],
#  116: ['works', 'great', 'upgraded', 'echo', 'dot', 'size', 'echo', 'happier'],
#  117: ['alexa', '....'],
#  118: ['upgraded', 'lilttle', 'echo', 'dot', 'happy', 'sound'],
#  119: ['excellent', 'product', 'set', 'ease'],
#  120: ['gen',
#   'echo',
#   'came',
#   'worked',
#   'purchased',
#   '2nd',
#   'gen',
#   'prime',
#   'day',
#   'far',
#   'happy',
#   'improved',
#   'speaker',
#   'provides',
#   'enhanced',
#   'sound',
#   'music'],
#  121: ['love',
#   'echo',
#   'smart',
#   'speaker',
#   'love',
#   'volume',
#   'clarity',
#   'easy',
#   'set',
#   'wonderful',
#   'gift',
#   'age'],
#  122: ['wonderful', 'product', 'fast', 'delivery'],
#  123: ['initially',
#   'harder',
#   'set',
#   'called',
#   'tech',
#   'knowledgeable',
#   'working',
#   'great'],
#  124: ['easy', 'set', 'family', 'love'],
#  125: ['great', 'sound', 'responsive', 'voice', 'commands'],
#  126: ['live',
#   'long',
#   'echo',
#   'enjoy',
#   'music',
#   'style',
#   'asking',
#   'alexa',
#   'going',
#   'greade',
#   'wireless',
#   'love',
#   'echo',
#   'love',
#   'alexa'],
#  127: ['cool', 'product', 'speaker', 'sounds', 'good', 'spotify', 'blasting'],
#  128: ['having',
#   'fun',
#   'alexa',
#   'love',
#   'able',
#   'listen',
#   'music',
#   'room',
#   'busy'],
#  129: ['far',
#   'nice',
#   'item',
#   'picks',
#   'voice',
#   'understands',
#   'problems',
#   'day',
#   'asked',
#   'turn',
#   'music',
#   'room',
#   'heard',
#   'fine',
#   'listen',
#   'music',
#   'check',
#   'weather',
#   'things'],
#  130: ['love', 'echo'],
#  131: ['love',
#   'helpful',
#   'use',
#   'remembering',
#   'things',
#   'sleep',
#   'ask',
#   'week',
#   'learning'],
#  132: ['better',
#   '1st',
#   'gen',
#   'way',
#   'miss',
#   'ring',
#   'volume',
#   'control',
#   'quicker',
#   'easier',
#   'grab',
#   'twist',
#   'having',
#   'look',
#   'buttons',
#   'find',
#   '34;-&#34',
#   'press',
#   'times',
#   'wish',
#   'bass',
#   'bit',
#   'better',
#   'great',
#   'device',
#   'happy'],
#  133: ['love', 'having', 'alexa'],
#  134: ['far', 'like', '🤓'],
#  135: ['thoroughly',
#   'enjoying',
#   'ecoo',
#   'love',
#   'read',
#   'audiobook',
#   'office',
#   'simply',
#   'open',
#   'audiobook',
#   'kindle',
#   'continue',
#   'wonderful',
#   'listening',
#   'music',
#   'mood',
#   'book',
#   'great',
#   'setting',
#   'reminders'],
#  136: ['love'],
#  137: ['love'],
#  138: ['love', 'sound', 'quality', 'unit', 'clear', 'sound'],
#  139: ['listening',
#   'talk',
#   'radio',
#   'morning',
#   'turning',
#   'lights',
#   'etc',
#   'system',
#   'excellent',
#   'job',
#   'house',
#   'sound',
#   'system',
#   'streaming',
#   'sirius'],
#  140: ['week',
#   'learning',
#   'alexa',
#   'learning',
#   'process',
#   'love',
#   'music',
#   'time',
#   'listen',
#   'podcasts',
#   'radio',
#   'stations',
#   'started',
#   'keeping',
#   'shopping',
#   'lists',
#   'grocery',
#   'lists',
#   'love',
#   'search',
#   'paper',
#   'pencil',
#   'getting',
#   'time',
#   'temperature',
#   'great',
#   'wait',
#   'weather',
#   'reports',
#   'sound',
#   'good',
#   'fussy',
#   'woofers',
#   'tweeters',
#   'base',
#   'etc',
#   'echo',
#   'fine',
#   'afternoon',
#   'going',
#   'try',
#   '“',
#   'dropping',
#   'in”.on',
#   'son',
#   'gets',
#   'home',
#   'going',
#   'surprise'],
#  141: ['features'],
#  142: ['great',
#   'sound',
#   'quality',
#   'great',
#   'features',
#   'great',
#   'product',
#   'multi',
#   'room',
#   'music',
#   'cool'],
#  143: ['cool'],
#  144: ['echo', 'bought', 'echo', 'qvc'],
#  145: ['annoying',
#   'alexa',
#   'able',
#   'downloaded',
#   'spend',
#   'time',
#   'trying',
#   'figure',
#   'phrase',
#   'machine',
#   'look'],
#  146: ['alexa',
#   'beginning',
#   'accidentally',
#   'spilled',
#   'water',
#   'replaced',
#   '2nd',
#   'generation',
#   'decided',
#   'echo',
#   'setup',
#   'easy',
#   'working',
#   'minutes'],
#  147: ['like',
#   'able',
#   'tell',
#   'alexia',
#   'music',
#   'want',
#   'hear',
#   'trouble',
#   'finding',
#   'song',
#   'specific',
#   'title'],
#  148: ['like',
#   'looks',
#   'better',
#   'original',
#   'echo',
#   'moved',
#   'old',
#   'echo',
#   'basement',
#   'family',
#   'room',
#   'nice',
#   'sound'],
#  149: ['echo',
#   'wonderful',
#   'learning',
#   'use',
#   'music',
#   'requests',
#   'somewhat',
#   'limited'],
#  150: ['know',
#   'half',
#   'things',
#   'asked',
#   'recognize',
#   'sprinkler',
#   'wifi',
#   'controller',
#   'product',
#   'details',
#   'says',
#   'compatible',
#   'program',
#   'change',
#   'wifi',
#   'thermostat',
#   'settings',
#   'matched',
#   'wifi',
#   'router',
#   'handy',
#   'music',
#   'player',
#   'amazon',
#   'music'],
#  151: ['love'],
#  152: ['awesome.understands', 'kids'],
#  153: ['pleasantly',
#   'surprised',
#   'sound',
#   'quality',
#   'features',
#   'nice',
#   'easily',
#   'hear',
#   'particular',
#   'artist',
#   'hear',
#   'books',
#   'simple',
#   'command',
#   'looking',
#   'forward',
#   'exploring',
#   'options',
#   'device'],
#  154: ['met', 'exceeded', 'expectations', 'easy', 'set', 'quick', 'responses'],
#  155: ['like',
#   'fact',
#   'kind',
#   'music',
#   'prime',
#   'want',
#   'request',
#   'alexa',
#   'liked',
#   'informative',
#   'photo',
#   'little',
#   'pamphlet',
#   'wish',
#   'included',
#   'connect',
#   'tv',
#   'etc',
#   'commands',
#   'alexa',
#   'love',
#   'having',
#   'music'],
#  156: ['found',
#   'way',
#   'access',
#   'echo',
#   'thorough',
#   'prime',
#   'account',
#   'think',
#   'line',
#   'video',
#   'music',
#   'etc',
#   'think',
#   'setup',
#   'app',
#   'define',
#   'example',
#   'music',
#   'like',
#   'integrated',
#   'echo',
#   'tried',
#   'ask',
#   'playlist',
#   'echo',
#   'sure',
#   'set',
#   'play',
#   'list',
#   'settings',
#   'like',
#   'fact',
#   'words',
#   'exact',
#   'match',
#   'playlist',
#   'names',
#   'remember',
#   'like',
#   'ready',
#   'nature',
#   'echo',
#   'respond',
#   'queries'],
#  157: ['great',
#   'item',
#   'added',
#   'audible',
#   'books',
#   'makes',
#   'better',
#   'thank'],
#  158: ['prime',
#   'day',
#   '2nd',
#   'gen',
#   'echo',
#   'sale',
#   'resist',
#   'beginning',
#   'smart',
#   'home',
#   'set',
#   'happier',
#   'alexa',
#   'amazing',
#   'job',
#   'connecting',
#   'smart',
#   'devices',
#   'thanks',
#   'control',
#   'lights',
#   'smart',
#   'plugs',
#   'tv',
#   'etc',
#   'trouble',
#   'connecting',
#   'echo',
#   'wifi',
#   'phone',
#   'app',
#   'works',
#   'perfectly',
#   'fine',
#   'let',
#   'add',
#   'skills',
#   'routines',
#   'smart',
#   'devices',
#   'timers',
#   'sound',
#   'quality',
#   'good',
#   'audiophile',
#   'alexa',
#   'hear',
#   'voice',
#   'watching',
#   'movies',
#   'high',
#   'volume',
#   'design',
#   'great',
#   'modern',
#   'definitely',
#   'add',
#   'nice',
#   'touch',
#   'home',
#   'change',
#   'covers',
#   'like',
#   'sale',
#   'overall',
#   'great',
#   'addition',
#   'home',
#   'enables',
#   'possibilities',
#   'sure',
#   'add',
#   'alexa',
#   'home'],
#  159: ['versatile', 'fun'],
#  160: ['works', 'great', 'killer', 'speaker', 'wife', 'son', 'love'],
#  161: ['regret',
#   'waiting',
#   'long',
#   'purchase',
#   'item',
#   'surprised',
#   'pleased',
#   'sound',
#   'quality'],
#  162: ['stopped',
#   'working',
#   '2',
#   'weeks',
#   'follow',
#   'commands',
#   'fun',
#   'working'],
#  163: ['far',
#   'love',
#   'working',
#   'getting',
#   'things',
#   'set',
#   'love',
#   'grocery',
#   'list',
#   'app'],
#  164: ['performs',
#   'pretty',
#   'expected',
#   'disappointed',
#   'provide',
#   'terminology',
#   'need',
#   'play',
#   'kinds',
#   'music',
#   'subscribing',
#   'amazon',
#   'music',
#   'service',
#   'understand',
#   'music',
#   'choices',
#   'limited',
#   'knowing',
#   'ask',
#   'access',
#   'music',
#   'provided',
#   'free',
#   'echo',
#   'purchase',
#   'chart',
#   'showing',
#   'language',
#   'need',
#   'use'],
#  165: ['easy', 'set'],
#  166: ['like', 'product', 'speakers', 'high', 'quality', 'expected'],
#  167: ['great', 'investment', 'alexa', 'helped', 'laugh'],
#  168: ['exho', 'home', 'love'],
#  169: ['love',
#   'plan',
#   'gender',
#   'music',
#   'big',
#   'band',
#   'jazz',
#   'easy',
#   'find',
#   'local',
#   'radio',
#   'sound',
#   'good',
#   'stop',
#   'voice',
#   'command',
#   'phone'],
#  170: ['good', 'value'],
#  171: ['super', 'easy', 'set', 'loving', 'new', 'echo'],
#  172: ['s', 'like', 'speaker', 'ask', 'alexa'],
#  173: ['best',
#   'father',
#   'day',
#   'gift',
#   'dad',
#   'joked',
#   'mom',
#   'alexa',
#   'listening',
#   'repeated',
#   'stories',
#   'going',
#   'forward'],
#  174: ['great',
#   'addition',
#   'breakfast',
#   'room',
#   'kitchen',
#   'tunes',
#   'information',
#   'instantly',
#   'available',
#   'slowly',
#   'learning',
#   'features'],
#  175: ['sound', 'quality'],
#  176: ['sad', 'joke', 'worthless'],
#  177: ['entertainment'],
#  178: ['good', 'quality'],
#  179: ['works',
#   'great',
#   'sounds',
#   'great',
#   'miss',
#   'beat',
#   'wish',
#   'battery',
#   'better',
#   'portability'],
#  180: ['loved', 'till', 'stoled', 'afford', 'replace', 'going'],
#  181: ['alexa', 'rocks'],
#  182: ['got',
#   'gift',
#   'love',
#   'bought',
#   '....',
#   'allows',
#   'play',
#   'music',
#   'amozon',
#   'prime',
#   'music',
#   'worth',
#   'gives',
#   'new',
#   'briefs',
#   'tells',
#   'jokes'],
#  183: [],
#  184: ['mom',
#   'bought',
#   'echo',
#   'dots',
#   'repeated',
#   'ask',
#   'great',
#   'told',
#   '“',
#   '”',
#   'days',
#   '6',
#   'hours',
#   'later',
#   'live',
#   'life',
#   'amazing',
#   'large',
#   'speakers',
#   'small',
#   'echo',
#   'dot',
#   'returning',
#   'going',
#   'order',
#   'alexa',
#   'speaker',
#   'big',
#   'echo',
#   'tou’ll',
#   'returning',
#   'echo',
#   'dots',
#   'live'],
#  185: ['love', 'great', 'product'],
#  186: ['easy', 'set', 'user', 'friendly'],
#  187: ['disappointed',
#   'alexa',
#   'plug',
#   'wall',
#   'socket',
#   'time',
#   'fault',
#   'checking',
#   'assumption',
#   'company',
#   'technologically',
#   'advanced',
#   'amazon',
#   'sell',
#   'product',
#   'rechargeable',
#   'battery',
#   'return',
#   'apple',
#   'music',
#   'boom',
#   'speaker',
#   'flexibility',
#   'alexa'],
#  188: ['think',
#   '34;2nd',
#   'gen&#34',
#   'sounds',
#   'good',
#   '1st',
#   'aux',
#   '...',
#   'add',
#   'external',
#   'speaker',
#   'going',
#   'dot',
#   '2nd',
#   'issue',
#   'unique',
#   'unit',
#   'understand',
#   'override',
#   'default',
#   'prevents',
#   'playing',
#   'blue',
#   'tooth',
#   'speaker',
#   'playing',
#   '34;group&#34',
#   'delay',
#   'bt',
#   'speaker',
#   'units',
#   'heard',
#   'able',
#   'play',
#   'group',
#   'bt',
#   'speaker'],
#  189: [],
#  190: ['like',
#   'interaction',
#   'asking',
#   'questions',
#   'like',
#   'ask',
#   'setup',
#   'schedule',
#   'connected',
#   'lamp'],
#  191: ['supberb',
#   'sound',
#   'definitely',
#   'worth',
#   'extra',
#   'money',
#   'listen',
#   'lots',
#   'music'],
#  192: ['love',
#   'amazon',
#   'echo',
#   'think',
#   'sound',
#   'quality',
#   'great',
#   'lot',
#   'fun',
#   'handy',
#   'music',
#   'updates',
#   'weather',
#   'sports'],
#  193: ['love', 'grandkids'],
#  194: ['far',
#   'worked',
#   'intuitive',
#   'link',
#   'different',
#   'devices',
#   'skills',
#   'getting',
#   'hang'],
#  195: ['works', 'advertised'],
#  196: ['love'],
#  197: ['love',
#   'new',
#   'addition',
#   'house',
#   'speaker',
#   'quality',
#   'great',
#   'love',
#   'alexa',
#   'complaints',
#   'suggestions',
#   'future',
#   'series',
#   'better',
#   'communication',
#   'ability',
#   'example',
#   'smart',
#   'lights',
#   'house',
#   'specify',
#   'kitchen',
#   'light',
#   '1',
#   'kitchen',
#   'light',
#   '2',
#   'prior',
#   'command',
#   'respond',
#   'says',
#   'recognize',
#   'want',
#   'alexa',
#   'respond',
#   'thank',
#   'repeat',
#   'alexa',
#   'thank',
#   'times',
#   'respond',
#   'husband',
#   'know',
#   'sounds',
#   'odd',
#   'laugh',
#   'maybe',
#   'southern',
#   'thing',
#   'want',
#   'alexa',
#   'manners'],
#  198: ['like', 'music', 'trivia', 'games', 'weather'],
#  199: ['described',
#   'received',
#   'time',
#   'like',
#   'automatic',
#   'enrolment',
#   'music'],
#  200: ['great', 'device'],
#  201: ['owned',
#   'echo',
#   'overa',
#   'year',
#   'new',
#   'lacks',
#   'easy',
#   'way',
#   'increase',
#   'decrease',
#   'volume',
#   'telling',
#   'increase',
#   'decrease',
#   'volume',
#   'hard',
#   'wife',
#   'english',
#   'second',
#   'language',
#   'born',
#   'korea',
#   'sound',
#   'echo',
#   'superb',
#   '..'],
#  202: ['love', 'kitchen', 'works'],
#  203: ['nice', 'impressed', 'wish'],
#  204: ['love', 'product', 'nice', 'easy', 'access', 'info'],
#  205: ['got',
#   'great',
#   'sound',
#   'bass',
#   'work',
#   'time',
#   'hot',
#   'miss',
#   'recognizes',
#   'things'],
#  206: ['discovering', 'echo'],
#  207: ['amazing', 'paroduct'],
#  208: ['good',
#   'hearing',
#   'range',
#   'sound',
#   'quality',
#   'bit',
#   'complicated',
#   'set',
#   'understand',
#   'lot',
#   'speaking',
#   'slowly',
#   'clearly',
#   'love',
#   'flash',
#   'briefing',
#   'feature',
#   'interfacing',
#   'abode',
#   'home',
#   'security',
#   'system'],
#  209: ['speaker', 'sounds', 'good'],
#  210: ['absolutely', 'love'],
#  211: ['best',
#   'product',
#   'control',
#   'thermostat',
#   'lights',
#   'house',
#   'dislike'],
#  212: ['thoroughly',
#   'enjoying',
#   'amazon',
#   'echo',
#   'installation',
#   'easy',
#   'alexa',
#   'app',
#   'purchased',
#   '2',
#   'kasa',
#   'smart',
#   'plugs',
#   'control',
#   'living',
#   'room',
#   'lights',
#   'installation',
#   'easy',
#   'kasa',
#   'app',
#   'sinqued',
#   'right',
#   'echo',
#   'enjoying',
#   'playing',
#   'music',
#   'echo',
#   'sound',
#   'quality',
#   'awesome',
#   'added',
#   'kasa',
#   'smart',
#   'bulb',
#   'kitchen',
#   'setup',
#   'seamless',
#   'looking',
#   'forward',
#   'adding',
#   'automation',
#   'home'],
#  213: ['home', 'entertainment'],
#  214: ['cool',
#   'product',
#   'easy',
#   'setup',
#   'fun',
#   'use',
#   'sound',
#   'quality',
#   'better',
#   'anticipated'],
#  215: ['love', 'great', 'sound', '...', 'easy', 'connect', 'use', '...'],
#  216: ['work',
#   'fairly',
#   'new',
#   'smart',
#   'tv',
#   'mainly',
#   'tv',
#   'manufacturers(lg',
#   'fault',
#   'supporting',
#   'older',
#   'tvs',
#   'year',
#   'smart',
#   'locks',
#   'need',
#   'additional',
#   'piece',
#   'equipment',
#   'order',
#   'connect',
#   'speakers',
#   'sound',
#   'great',
#   'works'],
#  217: ['great', 'sound', 'little', 'speaker'],
#  218: ['enjoy'],
#  219: [],
#  220: ['cool'],
#  221: ['good', 'quality', 'great', 'sound', 'quality'],
#  222: ['works', 'perfectly'],
#  223: ['great',
#   'product',
#   'alexa',
#   'understand',
#   'commands',
#   'fire',
#   'tv',
#   'fabulous',
#   'speaker'],
#  224: ['love', 'echo', 'great', 'sound', 'smart'],
#  225: ['sure', 'love'],
#  226: ['plays', 'great'],
#  227: ['works', 'absolutely', 'great'],
#  228: ['amazing', 'product', 'great', 'sound', 'quality'],
#  229: ['best', 'thing', 'invested', 'thank', '😁', '😁', '😁', '😁'],
#  230: ['extremely',
#   'impressed',
#   'item',
#   'bought',
#   '34;warehouse&#34',
#   '34;outlet&#34',
#   '34;minor',
#   'imperfection',
#   'tell',
#   'works',
#   'great',
#   'come',
#   'packaging',
#   'sealed',
#   'damage',
#   'missing',
#   'like',
#   'sound',
#   'quality',
#   'knock',
#   'bose',
#   'great',
#   'family',
#   'easy',
#   'use',
#   'minor',
#   'learning',
#   'curve',
#   'learns',
#   'voice',
#   'integrates',
#   'seamlessly',
#   'amazon',
#   'services',
#   "can't",
#   'wait',
#   'classroom',
#   'lot',
#   'fun',
#   'speaker',
#   'let',
#   'plan'],
#  231: ['love',
#   'echo',
#   'bedroom',
#   'wonderful',
#   'music',
#   'info',
#   'sleeping',
#   'sounds'],
#  232: ['awesome',
#   'life',
#   'changer',
#   'seriously',
#   'able',
#   'start',
#   'morning',
#   'alexa',
#   'having',
#   '34;wake&#34;me',
#   'alarm',
#   'playing',
#   'music',
#   'gotten',
#   'voice',
#   'room',
#   '34;listen&#34',
#   'love',
#   'echos',
#   'hesitate',
#   'price',
#   'speaker',
#   'unbelievable',
#   'buying',
#   'cordless',
#   'holder',
#   'echo',
#   'love',
#   'purchase',
#   'love',
#   'alexa'],
#  233: ['super',
#   'impressed',
#   'alexa',
#   'prime',
#   'lapsed',
#   'play',
#   'smart',
#   'differentiate',
#   'spotify',
#   'accounts',
#   'use',
#   'randomly',
#   'speaks',
#   'talking',
#   'today',
#   'unplugged',
#   '...',
#   'sure',
#   'use',
#   'alexa'],
#  234: ['like'],
#  235: ['liked', '100'],
#  236: ['issue',
#   'buying',
#   'use',
#   'electronics',
#   'long',
#   'good',
#   'like',
#   'new',
#   'read',
#   'comment'],
#  237: ['family', 'loves', 'new', 'echo'],
#  238: ['bought', 'wife', 'loves'],
#  239: ['fun', 'got', 'today', 'pod', 'car', 'use', 'house'],
#  240: ['like'],
#  241: ['echo',
#   'worth',
#   'penny',
#   'like',
#   'having',
#   '3',
#   'household',
#   'employees',
#   'small',
#   'flat',
#   'rate',
#   'bedrooms',
#   'living',
#   'room',
#   'drop',
#   'use',
#   'intercom',
#   'listen',
#   'music',
#   'answer',
#   'quick',
#   'questions',
#   'alarms',
#   'wake',
#   'school',
#   'etc'],
#  242: ['listen', 'music', 'set', 'timer'],
#  243: ['received',
#   'echo',
#   'perfect',
#   'condition',
#   'device',
#   'easy',
#   'set',
#   'responds',
#   'quickly',
#   'issues',
#   'alexa',
#   'great',
#   'addition',
#   'family'],
#  244: ['good',
#   'sound',
#   'like',
#   'music',
#   'scheduling',
#   'like',
#   'random',
#   'thoughts',
#   'recorded',
#   'think',
#   'jokes',
#   'cute'],
#  245: ['purchased',
#   'beginning',
#   'learn',
#   'far',
#   'pleased',
#   'amazed',
#   'different',
#   'actions',
#   'perform',
#   'enjoying',
#   'looking',
#   'forward',
#   'learning',
#   'options',
#   'provides'],
#  246: ['echo', 'great', 'smaller'],
#  247: ['funny',
#   'buy',
#   'looks',
#   'fun',
#   'winds',
#   'totally',
#   'useful',
#   'home',
#   'loving'],
#  248: ['bought',
#   'replace',
#   '34;dot&#34',
#   'living',
#   'room',
#   'speaker',
#   'slightly',
#   'better',
#   'hears',
#   'better',
#   'tv',
#   'unfortunately',
#   'understand',
#   'respond',
#   'requests',
#   'dot',
#   'frequently',
#   'request',
#   '2',
#   '3',
#   'times',
#   'want',
#   'dot',
#   'usually',
#   'exactly',
#   'want',
#   'request',
#   'consider',
#   'upgrade'],
#  249: ['good',
#   'experience',
#   'far',
#   'second',
#   'generation',
#   'echo',
#   'things',
#   'learn',
#   'time',
#   'right',
#   'enjoying',
#   'music',
#   'weather',
#   'updates',
#   'alarm',
#   'feature',
#   'personality',
#   'purchased',
#   'mini',
#   'smart',
#   'socket',
#   'yes',
#   'excited',
#   'begin'],
#  250: ['having',
#   'trouble',
#   'connecting',
#   'tv',
#   'exactly',
#   'tech',
#   'smart',
#   'sure',
#   'grandsons',
#   'figure',
#   'far',
#   'music'],
#  251: ['simply',
#   'love',
#   'echo',
#   'hardly',
#   'watch',
#   'tv',
#   'anymore',
#   'busy',
#   'listening',
#   'music',
#   'speaker',
#   'pretty',
#   'goo',
#   'size',
#   'fun',
#   'skills',
#   'echo',
#   'fun',
#   'family'],
#  252: ['enjoyed', 'entire', 'echo', 'experience'],
#  253: ['easy', 'set'],
#  254: ['echo',
#   'amazing',
#   'device',
#   'times',
#   'intuitive',
#   'times',
#   'ask',
#   'clear',
#   'simple',
#   'result',
#   'installation',
#   'fairly',
#   'straightforward',
#   'messed',
#   'times',
#   'simply',
#   'thought',
#   'step',
#   'complete',
#   'actually',
#   'lose',
#   'ground',
#   'figured',
#   'advice',
#   'patient',
#   'app',
#   'let',
#   'know',
#   'step',
#   'biggest',
#   'issue',
#   'moment',
#   'echo',
#   'devices',
#   'home',
#   'like',
#   'use',
#   'intercoms',
#   'told',
#   'echos',
#   'aware',
#   'existence',
#   'ask',
#   'alexa',
#   'answers',
#   'instructions',
#   'change',
#   'know',
#   'likely',
#   'fault',
#   'think',
#   'designers',
#   'anticipate',
#   'easier',
#   'find',
#   'needed',
#   'instructions',
#   'small',
#   'deal',
#   'device',
#   'savvy',
#   'people',
#   'challenge'],
#  255: ['loving'],
#  256: ['original',
#   'alexa',
#   'tap',
#   'far',
#   '2nd',
#   'generation',
#   'best',
#   'happy',
#   'making',
#   'improvements',
#   'new',
#   'great',
#   'updates',
#   'little',
#   'a.i.',
#   'think',
#   'help',
#   'lot',
#   'bugs',
#   'happy',
#   'play',
#   'music',
#   'house',
#   'adjust',
#   'bass',
#   'treble',
#   'thank'],
#  257: ['pleased',
#   'echo',
#   '2nd',
#   'generation',
#   'nice',
#   'alexa',
#   'available',
#   'music',
#   'weather',
#   'news',
#   'probably',
#   'lot',
#   'discovered'],
#  258: ['pleasantly',
#   'surprised',
#   'sound',
#   'quality',
#   'echo',
#   'big',
#   'fan',
#   'deep',
#   'bass',
#   'sufficient',
#   'potential',
#   'control',
#   'home',
#   'option',
#   'explore',
#   'evolve',
#   'home',
#   'smart',
#   'home',
#   'voice',
#   'recognition',
#   'impressive',
#   'stylish',
#   'fun',
#   'regrets',
#   'purchase',
#   'great',
#   'technically',
#   'changes',
#   'people',
#   'ask',
#   'play',
#   'song',
#   'movie',
#   'responds',
#   'instantly',
#   'elderly',
#   'loved',
#   'great',
#   'gift',
#   'connected',
#   'wifi',
#   'simple',
#   'use',
#   'want',
#   'unlimited',
#   'music',
#   'control',
#   'sure',
#   'amazon',
#   'prime',
#   'premium',
#   'spotify',
#   'blown',
#   'away',
#   'personal',
#   'dj',
#   'conversations',
#   'echo',
#   'embarrassed',
#   'echo',
#   'laugh',
#   'couple',
#   'times',
#   'ask',
#   'tell',
#   'joke',
#   'tells',
#   'packages',
#   'amazon',
#   'prime',
#   'addict',
#   'comes',
#   'extremely',
#   'handy'],
#  259: ['easy', 'setup', 'love', 'things'],
#  260: ['alexa', 'house----the', 'future', 'arrived'],
#  261: ['alexa',
#   'amazon',
#   'find',
#   'today',
#   'resist',
#   'getting',
#   'echo',
#   'best',
#   'thing',
#   'use',
#   'house',
#   'happier'],
#  262: ['arrived', 'expected'],
#  263: ['bought',
#   'weeks',
#   'ago',
#   'product',
#   'excellent',
#   'forget',
#   'buy',
#   'charger',
#   'ordering',
#   'outside',
#   'pool',
#   'worry',
#   'hiring',
#   'electrician',
#   'outlets',
#   'yard'],
#  264: ['terrific'],
#  265: ['love', 'echo'],
#  266: ['smaller', 'original', 'looks', 'nicer'],
#  267: ['works', 'great'],
#  268: ['husband',
#   '34;late',
#   'adopters&#34',
#   'come',
#   'technology',
#   'decide',
#   'try',
#   'echo',
#   'serve',
#   'primarily',
#   'music',
#   'source',
#   'wow',
#   'amazed',
#   'great',
#   'sound',
#   'having',
#   'great',
#   'time',
#   'listening',
#   'favorite',
#   'songs',
#   'buy',
#   'asking',
#   'alexa',
#   'buy',
#   'elderly',
#   'dad',
#   'think',
#   'enjoy',
#   'having',
#   'listen',
#   'music',
#   'place',
#   'calls'],
#  269: ['enjoyed',
#   'changing',
#   'directv',
#   'channels',
#   'plays',
#   'iheartradio',
#   'pandora',
#   'adjusts',
#   'ac',
#   'thermostat',
#   'turns',
#   'living',
#   'room',
#   'lights',
#   'outside',
#   'lights'],
#  270: ['wanting', 'bought', 'prime', 'day', 'absolutely', 'love'],
#  271: ['glad',
#   'got',
#   'echo',
#   'bluetooth',
#   'speaker',
#   'alexa',
#   'stuff',
#   'non',
#   'smart',
#   'speakers',
#   'personally',
#   'love',
#   'timer',
#   'feature',
#   'helped',
#   'cooking',
#   'multiple',
#   'things',
#   'simultaneously',
#   'pandora',
#   'integration',
#   'feature',
#   'use',
#   'daily',
#   'happy',
#   'prime',
#   'day',
#   'purchase',
#   'echo',
#   'hub',
#   'echo',
#   'dots',
#   'future'],
#  272: ['subject', 'line', 'love'],
#  273: ['love'],
#  274: ['easy', 'setup'],
#  275: ['hesitant',
#   'buy',
#   'echo',
#   'echo',
#   'dot',
#   'good',
#   'echo',
#   'sound',
#   'quality',
#   'feel',
#   'needed',
#   'glad',
#   'got',
#   'difference',
#   'sound',
#   'far',
#   'superior',
#   'echo',
#   'dot',
#   'listen',
#   'greatest',
#   'showman',
#   'little',
#   'power'],
#  276: ['sound', 'quality', 'great', 'learning', 'different', 'things', 'fun'],
#  277: ['got',
#   'good',
#   'deal',
#   'works',
#   'great',
#   'prime',
#   'setup',
#   'bit',
#   'pain',
#   'fault',
#   'crappy',
#   'internet',
#   'service',
#   'worked',
#   'great',
#   'nice',
#   'sound',
#   'small',
#   'speaker'],
#  278: ['love'],
#  279: ['works', 'great', 'perfect', 'office'],
#  280: ['love',
#   'it---',
#   'inside',
#   'house',
#   'pool',
#   'good',
#   'bose',
#   'speakers',
#   'house'],
#  281: ['easy', 'use', '--', 'amazing'],
#  282: ['nice', 'product', 'a+'],
#  283: ['love',
#   'echo',
#   'totally',
#   'amazed',
#   'speaker',
#   'quality',
#   'bummed',
#   'buy',
#   'got',
#   'prime',
#   'day'],
#  284: ['responsive', 'great', 'sound', 'quality', 'size'],
#  285: ['efficient', 'amazing', 'cool', 'use', 'day', '...'],
#  286: ['impressed',
#   'quality',
#   'sound',
#   'echo',
#   'definitely',
#   'comparable',
#   'bose',
#   'mini',
#   'gave',
#   '4',
#   'stars',
#   'use',
#   'apple',
#   'music',
#   'account'],
#  287: ['technology',
#   'small',
#   'device',
#   'price',
#   'good',
#   'sound',
#   'amazing',
#   'feature',
#   'home'],
#  288: ['mainly', 'use', 'music', 'learning', 'time', 'bad'],
#  289: ['replaced',
#   '1st',
#   'gen',
#   'concerned',
#   'smaller',
#   'unit',
#   'having',
#   'sound',
#   '...',
#   'wrong',
#   'volume',
#   'clear',
#   'good',
#   'product'],
#  290: ['great', 'addition', 'echo', 'plus'],
#  291: ['best'],
#  292: ['love', 'feature', 'play', 'music', 'room', 'multiple', 'echos'],
#  293: ['love', 'alexa', 'surprised', 'use'],
#  294: ['use', 'product', 'enjoyment', 'love'],
#  295: ['easy',
#   'use',
#   'great',
#   'sound',
#   '...',
#   'great',
#   'purchase',
#   'great',
#   'price'],
#  296: ['easy', 'set', 'issues'],
#  297: ['unit',
#   'add',
#   'pleasure',
#   'echo',
#   'plus',
#   'music',
#   'information',
#   'home',
#   'room'],
#  298: ['extremely',
#   'useful',
#   'simple',
#   'things',
#   'like',
#   'spotify',
#   'audible',
#   'things',
#   'like',
#   'answer',
#   'ask',
#   'nice',
#   'use'],
#  299: ['difficult', 'set', 'keeps', 'timing', 'enter', 'password'],
#  300: ['getting',
#   'use',
#   'echo',
#   'shopping',
#   'lists',
#   'listening',
#   'music',
#   'timer',
#   'working',
#   'great',
#   'far'],
#  301: ['cool', 'lots', 'fun', 'week', 'learning', 'capabilities'],
#  302: ['love', 'love'],
#  303: ['love', 'having', 'hard', 'time', 'setting', 'apps'],
#  304: ['use', 'office', 'apartment', 'music', 'information'],
#  305: ['great', 'music', 'little', 'hard', 'figure', 'works'],
#  306: ['given',
#   '7',
#   'year',
#   'time',
#   'birthday',
#   'gift',
#   'dad',
#   'loves',
#   'ask',
#   'alexa',
#   'answer',
#   'plus',
#   'good',
#   'homework',
#   'purchased',
#   'prime',
#   'day',
#   'bathroom',
#   'getting',
#   'ready',
#   'work',
#   'listen',
#   'music',
#   '4',
#   'a.m.',
#   'base',
#   'metro',
#   'booming',
#   '..',
#   'replacement',
#   'clock',
#   'radio',
#   'plus',
#   'echo',
#   'dot',
#   'night',
#   'stand',
#   'alarm',
#   'clock',
#   '..'],
#  307: ['impressed', 'look', 'clarity', 'sound', 'color'],
#  308: ['alexa', 'amazing', 'great', 'speaker'],
#  309: ['getting',
#   'alexa',
#   'connected',
#   'tv',
#   'things',
#   'right',
#   'use',
#   'music',
#   'information',
#   'great'],
#  310: ['works',
#   'sounds',
#   'great',
#   'house',
#   'barely',
#   '1100sf',
#   'sitting',
#   'kitchen',
#   'counter',
#   'hear',
#   'speak',
#   'room',
#   'lots',
#   'functionality',
#   'discover'],
#  311: ['pure',
#   'fun',
#   'echo',
#   'weather',
#   'jokes',
#   'news',
#   'briefing',
#   'music',
#   'use',
#   'lot',
#   'fun',
#   'money'],
#  312: ['use', 'time', 'especially', 'communicate', 'kids', 'home'],
#  313: ['love',
#   'learning',
#   'makes',
#   'lot',
#   'things',
#   'easier',
#   'like',
#   'forget',
#   'turn',
#   'light',
#   'room',
#   'ask',
#   'alexa',
#   'turn',
#   'light'],
#  314: ['bought',
#   'daughter',
#   'turned',
#   '9',
#   'loves',
#   'especially',
#   'like',
#   'calling',
#   'feature',
#   'cell',
#   'phone',
#   'loves',
#   'playing',
#   'music',
#   'dancing',
#   'amazon',
#   'music',
#   'play',
#   'favorite',
#   'songs',
#   '......',
#   'lol'],
#  315: ['got',
#   'wedding',
#   'gift',
#   'discovered',
#   'features',
#   'update',
#   'playing',
#   'music',
#   'great'],
#  316: ['impressed', 'sound', 'quality'],
#  317: ['pleased',
#   'purchase',
#   'echo',
#   'smart',
#   'speaker',
#   'love',
#   'fact',
#   'play',
#   'music',
#   'different',
#   'genre',
#   'want',
#   'trouble',
#   'wi',
#   'fi',
#   'working'],
#  318: ['wife',
#   'enjoy',
#   'ease',
#   'playing',
#   'music',
#   'games',
#   'fun',
#   'entertaining',
#   'look',
#   'forward',
#   'adding',
#   'smart',
#   'products',
#   'home'],
#  319: ['second',
#   'echo',
#   'love',
#   'helps',
#   'kitchen',
#   'set',
#   'timers',
#   'listen',
#   'news',
#   'prepare',
#   'grocery',
#   'lists',
#   'great',
#   'music'],
#  320: ['sound', 'quality', 'good', 'wish', 'alexa', 'answer', 'questions'],
#  321: ['second',
#   'echo',
#   'dot',
#   'speaker',
#   'weak',
#   'purchased',
#   'listening',
#   'music',
#   'speaker',
#   'great'],
#  322: ['great', 'sound'],
#  323: ['great'],
#  324: ['use', 'speaker', 'stream', 'music', '7', 'months', 'kinda', 'useless'],
#  325: ['set',
#   'user',
#   'friendly',
#   'set',
#   'user',
#   'friendly',
#   'hoped',
#   '..',
#   'alexa',
#   'app',
#   'able',
#   'download',
#   'pc',
#   'installing',
#   'invasive',
#   'drivers',
#   'wife',
#   'retired',
#   'able',
#   'install',
#   'alexa',
#   'son',
#   'supplying',
#   'smart',
#   'phone',
#   'alexa'],
#  326: ['easy', 'set', 'enjoying'],
#  327: ['echo',
#   'come',
#   'built',
#   'battery',
#   'plugged',
#   'times',
#   'use',
#   'makes',
#   'inconvenient'],
#  328: ['compact', 'bit', 'better', 'original'],
#  329: ['love', 'pretty', 'cool'],
#  330: ['having',
#   'living',
#   'room',
#   'music',
#   'sounds',
#   'good',
#   'living',
#   'room',
#   'hear',
#   'upstairs'],
#  331: ['great', 'product', 'set', 'easy', 'sound', 'wonderful'],
#  332: ['far', 'like', 'bought', 'music', 'sounds', 'pretty', 'good'],
#  333: ['love'],
#  334: ['love'],
#  335: ['glad', 'bought'],
#  336: ['like', 'types', 'fun', 'music'],
#  337: ['like', 'volume', 'turn', 'quickly'],
#  338: ['capabilities', 'program', 'grandkids', 'lve'],
#  339: ['love',
#   'new',
#   'echo',
#   'gives',
#   'hours',
#   'music',
#   'help',
#   'things',
#   'difficult',
#   'set',
#   'help',
#   'tekkie'],
#  340: ['good', 'bose', 'love', 'house', 'music'],
#  341: ['alexa', 'hardly', 'came', '..'],
#  342: ['easy',
#   'setup',
#   'app',
#   'easy',
#   'install',
#   'phone',
#   'sound',
#   'quality',
#   'listening',
#   'music',
#   'pandora',
#   'wonderful'],
#  343: ['learning', 'use', 'echo', 'far', 'love'],
#  344: ['works', 'awesome'],
#  345: ['works', 'great'],
#  346: ['small', 'speaker', 'sounds', 'great'],
#  347: ['great', 'sound', 'size', 'prize', 'course', '....', 'alexa'],
#  348: ['echo', 'definitely', 'need'],
#  349: ['great', 'device', 'work', 'better', '1st', 'generation'],
#  350: ['item',
#   'longer',
#   'works',
#   '5',
#   'months',
#   'use',
#   'connect',
#   'wifi',
#   'unresponsive',
#   'reset',
#   'requests'],
#  351: ['love',
#   'echo',
#   'dot',
#   'easy',
#   'fun',
#   'drop',
#   'grandaughter',
#   'lives',
#   '2000',
#   'miles',
#   'away',
#   'sounds',
#   'like',
#   'right'],
#  352: ['works', 'great', 'different', 'new', 'ones'],
#  353: ['going', 'kitchen', 'timer', 'music', 'duty'],
#  354: ['love',
#   'volume',
#   'definitely',
#   'use',
#   'boost',
#   'better',
#   'built',
#   'speaker',
#   'definitively',
#   '5',
#   'star',
#   'thought',
#   'ahead',
#   'audio',
#   'auxiliary',
#   'input',
#   'bought',
#   'dedicated',
#   'speaker',
#   'echo',
#   'proved',
#   'best',
#   'way'],
#  355: ['works', 'fine'],
#  356: ['works',
#   'great',
#   'looks',
#   'brand',
#   'new',
#   'love',
#   'new',
#   'echo',
#   'dot',
#   'getting',
#   'main',
#   'rooms',
#   'house'],
#  357: ['refurbished',
#   'item',
#   '..',
#   'works',
#   'like',
#   'new',
#   '...',
#   'love',
#   '...',
#   'easy',
#   'set',
#   'love',
#   'issue',
#   'volume',
#   'listening',
#   'relaxing',
#   'fine',
#   'expecting',
#   'recommend',
#   'purchasing',
#   'speaker'],
#  358: ['loud'],
#  359: ['2nd', 'love'],
#  360: ['sure',
#   'feel',
#   'echo',
#   'dot',
#   'things',
#   'need',
#   'ask',
#   'right',
#   'questions',
#   'understand'],
#  361: ['thing',
#   'barely',
#   'works',
#   'select',
#   '3rd',
#   'party',
#   'apps',
#   'stuff',
#   'think',
#   'box',
#   'sending',
#   'asap',
#   'waste',
#   'money'],
#  362: ['gift',
#   'man',
#   'like',
#   'plug',
#   'pictures',
#   'cord',
#   'prefer',
#   'cordless',
#   'works',
#   'purpose',
#   'bought'],
#  363: ['5th',
#   'amazon',
#   'echo',
#   'device',
#   'purchased',
#   'refurbished',
#   'satisfied',
#   'time',
#   'different',
#   'tell',
#   'brand',
#   'new',
#   'price',
#   '10',
#   'cheaper',
#   'echo',
#   'wake',
#   'timers',
#   'play',
#   'music',
#   'act',
#   'encyclopedias',
#   'turn',
#   'lights'],
#  364: ['small',
#   'echo',
#   'dot',
#   'amazing',
#   'sounds',
#   'come',
#   'great.it',
#   'changes',
#   'nest',
#   'thermostat',
#   'phillips',
#   'hue',
#   'lights.without',
#   'leaving',
#   'chair'],
#  365: ['talk', 'time', 'songs', 'dislikes', 'device'],
#  366: ['disappointed', 'amazons', 'technology'],
#  367: ['worked', 'promised'],
#  368: ['returned',
#   '2',
#   'echo',
#   'dots',
#   'getting',
#   'refund',
#   '1',
#   'returned',
#   '2',
#   'package',
#   'want',
#   'refunds',
#   'package'],
#  369: ['working'],
#  370: ['weird', 'pauses', 'speech', 'pattern', 'present', 'echo', 'devices'],
#  371: ['sure', 'love', 'alexa', 'lol', 'thank', 'great', 'price', 'product'],
#  372: ['works'],
#  373: ['echo', 'fan', 'work'],
#  374: [],
#  375: ['bought', 'bathroom', 'listen', 'shower', 'love'],
#  376: ['respond',
#   'spoken',
#   'promp',
#   'word',
#   'thought',
#   'connect',
#   'echo',
#   'upstairs',
#   'use',
#   'like',
#   'intercom',
#   'able'],
#  377: ['fast', 'shipping', 'works'],
#  378: ['love'],
#  379: ['love', 'love', 'love', 'new', 'free', 'assistant', ':)'],
#  380: ['words', '34;alexa', 'tell', 'poop', 'joke.&#34'],
#  381: ['worked',
#   'month',
#   'stopped',
#   'tried',
#   'try',
#   'work',
#   'working',
#   'want',
#   'refund'],
#  382: ['poor', 'quality', 'gave', 'away'],
#  383: ['refurbished', 'way', 'echo', 'works', 'like', 'new'],
#  384: ['love'],
#  385: ['need'],
#  386: ['speakers', 'loud', '..', 'alexa', 'great', 'naw'],
#  387: ['works', 'great', 'sounds', 'good'],
#  388: ['work',
#   'techie',
#   'friend',
#   'looked',
#   'said',
#   'adapter',
#   'strong',
#   'power',
#   'looked',
#   'like',
#   'bought',
#   'dollar',
#   'store',
#   'going',
#   'replace',
#   'adapter',
#   'hope',
#   'works'],
#  389: ['like', 'having', 'star', 'trek', 'home', 'fun', 'try', 'outsmart'],
#  390: ['add',
#   'echo',
#   'system',
#   'refurbished',
#   'product',
#   'works',
#   'like',
#   'new'],
#  391: ['great',
#   'office',
#   'use',
#   'daily',
#   'ways',
#   'include',
#   'spelling',
#   'background',
#   'music'],
#  392: ['awesome', 'love', 'alexa'],
#  393: ['sure', 'wanted', 'extremely', 'useful', 'love'],
#  394: ['initially',
#   'echo',
#   'dot',
#   'worked',
#   'time',
#   'dot',
#   'stopped',
#   'responding',
#   'alexa',
#   'foot',
#   'yelling',
#   'echos',
#   'echo',
#   'dots',
#   'rooms',
#   'respond',
#   'response',
#   'echo',
#   'dot',
#   'recommend',
#   'buying',
#   'refurbished'],
#  395: ['great', 'product', 'fast', 'shipping'],
#  396: ['bought',
#   'echo',
#   'dot',
#   'refurbished',
#   'stops',
#   'function',
#   'performing',
#   'wake',
#   'time',
#   'randomly',
#   'turns',
#   'buy',
#   'refurbished',
#   'echo',
#   'dot'],
#  397: ['perfect', 'works', 'great', 'problems', 'refurbished'],
#  398: ['trust', '....'],
#  399: ['perfect', 'condition', 'love', 'echo'],
#  400: ['love',
#   'beautiful',
#   'experience',
#   'especially',
#   'hooked',
#   'smart',
#   'lighting',
#   'accessories'],
#  401: ['got',
#   'couple',
#   'weeks',
#   'tell',
#   'issues',
#   'son',
#   'wanted',
#   '34;alexa&#34',
#   '6th',
#   'birthday',
#   'tell',
#   'jokes',
#   'ask',
#   'questions',
#   'listen',
#   'music',
#   'enjoy',
#   'bought',
#   'second',
#   'week',
#   'prime',
#   'deals',
#   'day'],
#  402: ['divertido'],
#  403: ['great', 'product', 'works', 'great'],
#  404: ['bought',
#   'guest',
#   'room',
#   'radio',
#   'alarm',
#   'clock',
#   'information\u200b',
#   'center'],
#  405: ['great',
#   'buy',
#   'bought',
#   'echo',
#   'love',
#   'speaker',
#   'best',
#   'music',
#   'works',
#   'great',
#   'kitchen',
#   'timers',
#   'alarms'],
#  406: [],
#  407: ['works',
#   'perfect',
#   'save',
#   'bucks',
#   'buy',
#   'refurbished',
#   'looks',
#   'brand',
#   'new'],
#  408: ['looks', 'works', 'perfect', 'glad', 'got', 'good', 'deal'],
#  409: ['good', 'new', 'bought', '10.00'],
#  410: ['love', 'works'],
#  411: ['perfect'],
#  412: ['good', 'price', 'prompt', 'shipping', 'working', 'flawlessly'],
#  413: ['love', 'alexa'],
#  414: ['room',
#   'improvement',
#   'price',
#   'complain',
#   'complain',
#   'audio',
#   'terrible',
# ...
#   'features'],
#  870: ['sound', 'quality'],
#  871: ['sad', 'joke', 'worthless'],
#  872: ['entertainment'],
#  873: ['good', 'quality'],
#  874: ['works',
#   'great',
#   'sounds',
#   'great',
#   'miss',
#   'beat',
#   'wish',
#   'battery',
#   'better',
#   'portability'],
#  875: ['loved', 'till', 'stoled', 'afford', 'replace', 'going'],
#  876: ['alexa', 'rocks'],
#  877: ['got',
#   'gift',
#   'love',
#   'bought',
#   '....',
#   'allows',
#   'play',
#   'music',
#   'amozon',
#   'prime',
#   'music',
#   'worth',
#   'gives',
#   'new',
#   'briefs',
#   'tells',
#   'jokes'],
#  878: [],
#  879: ['mom',
#   'bought',
#   'echo',
#   'dots',
#   'repeated',
#   'ask',
#   'great',
#   'told',
#   '“',
#   '”',
#   'days',
#   '6',
#   'hours',
#   'later',
#   'live',
#   'life',
#   'amazing',
#   'large',
#   'speakers',
#   'small',
#   'echo',
#   'dot',
#   'returning',
#   'going',
#   'order',
#   'alexa',
#   'speaker',
#   'big',
#   'echo',
#   'tou’ll',
#   'returning',
#   'echo',
#   'dots',
#   'live'],
#  880: ['love', 'great', 'product'],
#  881: ['easy', 'set', 'user', 'friendly'],
#  882: ['disappointed',
#   'alexa',
#   'plug',
#   'wall',
#   'socket',
#   'time',
#   'fault',
#   'checking',
#   'assumption',
#   'company',
#   'technologically',
#   'advanced',
#   'amazon',
#   'sell',
#   'product',
#   'rechargeable',
#   'battery',
#   'return',
#   'apple',
#   'music',
#   'boom',
#   'speaker',
#   'flexibility',
#   'alexa'],
#  883: ['think',
#   '34;2nd',
#   'gen&#34',
#   'sounds',
#   'good',
#   '1st',
#   'aux',
#   '...',
#   'add',
#   'external',
#   'speaker',
#   'going',
#   'dot',
#   '2nd',
#   'issue',
#   'unique',
#   'unit',
#   'understand',
#   'override',
#   'default',
#   'prevents',
#   'playing',
#   'blue',
#   'tooth',
#   'speaker',
#   'playing',
#   '34;group&#34',
#   'delay',
#   'bt',
#   'speaker',
#   'units',
#   'heard',
#   'able',
#   'play',
#   'group',
#   'bt',
#   'speaker'],
#  884: [],
#  885: ['like',
#   'interaction',
#   'asking',
#   'questions',
#   'like',
#   'ask',
#   'setup',
#   'schedule',
#   'connected',
#   'lamp'],
#  886: ['supberb',
#   'sound',
#   'definitely',
#   'worth',
#   'extra',
#   'money',
#   'listen',
#   'lots',
#   'music'],
#  887: ['love',
#   'amazon',
#   'echo',
#   'think',
#   'sound',
#   'quality',
#   'great',
#   'lot',
#   'fun',
#   'handy',
#   'music',
#   'updates',
#   'weather',
#   'sports'],
#  888: ['love', 'grandkids'],
#  889: ['far',
#   'worked',
#   'intuitive',
#   'link',
#   'different',
#   'devices',
#   'skills',
#   'getting',
#   'hang'],
#  890: ['works', 'advertised'],
#  891: ['love'],
#  892: ['love',
#   'new',
#   'addition',
#   'house',
#   'speaker',
#   'quality',
#   'great',
#   'love',
#   'alexa',
#   'complaints',
#   'suggestions',
#   'future',
#   'series',
#   'better',
#   'communication',
#   'ability',
#   'example',
#   'smart',
#   'lights',
#   'house',
#   'specify',
#   'kitchen',
#   'light',
#   '1',
#   'kitchen',
#   'light',
#   '2',
#   'prior',
#   'command',
#   'respond',
#   'says',
#   'recognize',
#   'want',
#   'alexa',
#   'respond',
#   'thank',
#   'repeat',
#   'alexa',
#   'thank',
#   'times',
#   'respond',
#   'husband',
#   'know',
#   'sounds',
#   'odd',
#   'laugh',
#   'maybe',
#   'southern',
#   'thing',
#   'want',
#   'alexa',
#   'manners'],
#  893: ['like', 'music', 'trivia', 'games', 'weather'],
#  894: ['described',
#   'received',
#   'time',
#   'like',
#   'automatic',
#   'enrolment',
#   'music'],
#  895: ['great', 'device'],
#  896: ['owned',
#   'echo',
#   'overa',
#   'year',
#   'new',
#   'lacks',
#   'easy',
#   'way',
#   'increase',
#   'decrease',
#   'volume',
#   'telling',
#   'increase',
#   'decrease',
#   'volume',
#   'hard',
#   'wife',
#   'english',
#   'second',
#   'language',
#   'born',
#   'korea',
#   'sound',
#   'echo',
#   'superb',
#   '..'],
#  897: ['love', 'kitchen', 'works'],
#  898: ['nice', 'impressed', 'wish'],
#  899: ['love', 'product', 'nice', 'easy', 'access', 'info'],
#  900: ['got',
#   'great',
#   'sound',
#   'bass',
#   'work',
#   'time',
#   'hot',
#   'miss',
#   'recognizes',
#   'things'],
#  901: ['discovering', 'echo'],
#  902: ['amazing', 'paroduct'],
#  903: ['good',
#   'hearing',
#   'range',
#   'sound',
#   'quality',
#   'bit',
#   'complicated',
#   'set',
#   'understand',
#   'lot',
#   'speaking',
#   'slowly',
#   'clearly',
#   'love',
#   'flash',
#   'briefing',
#   'feature',
#   'interfacing',
#   'abode',
#   'home',
#   'security',
#   'system'],
#  904: ['speaker', 'sounds', 'good'],
#  905: ['absolutely', 'love'],
#  906: ['best',
#   'product',
#   'control',
#   'thermostat',
#   'lights',
#   'house',
#   'dislike'],
#  907: ['thoroughly',
#   'enjoying',
#   'amazon',
#   'echo',
#   'installation',
#   'easy',
#   'alexa',
#   'app',
#   'purchased',
#   '2',
#   'kasa',
#   'smart',
#   'plugs',
#   'control',
#   'living',
#   'room',
#   'lights',
#   'installation',
#   'easy',
#   'kasa',
#   'app',
#   'sinqued',
#   'right',
#   'echo',
#   'enjoying',
#   'playing',
#   'music',
#   'echo',
#   'sound',
#   'quality',
#   'awesome',
#   'added',
#   'kasa',
#   'smart',
#   'bulb',
#   'kitchen',
#   'setup',
#   'seamless',
#   'looking',
#   'forward',
#   'adding',
#   'automation',
#   'home'],
#  908: ['home', 'entertainment'],
#  909: ['cool',
#   'product',
#   'easy',
#   'setup',
#   'fun',
#   'use',
#   'sound',
#   'quality',
#   'better',
#   'anticipated'],
#  910: ['love', 'great', 'sound', '...', 'easy', 'connect', 'use', '...'],
#  911: ['work',
#   'fairly',
#   'new',
#   'smart',
#   'tv',
#   'mainly',
#   'tv',
#   'manufacturers(lg',
#   'fault',
#   'supporting',
#   'older',
#   'tvs',
#   'year',
#   'smart',
#   'locks',
#   'need',
#   'additional',
#   'piece',
#   'equipment',
#   'order',
#   'connect',
#   'speakers',
#   'sound',
#   'great',
#   'works'],
#  912: ['great', 'sound', 'little', 'speaker'],
#  913: ['enjoy'],
#  914: [],
#  915: ['cool'],
#  916: ['good', 'quality', 'great', 'sound', 'quality'],
#  917: ['works', 'perfectly'],
#  918: ['great',
#   'product',
#   'alexa',
#   'understand',
#   'commands',
#   'fire',
#   'tv',
#   'fabulous',
#   'speaker'],
#  919: ['love', 'echo', 'great', 'sound', 'smart'],
#  920: ['sure', 'love'],
#  921: ['plays', 'great'],
#  922: ['works', 'absolutely', 'great'],
#  923: ['amazing', 'product', 'great', 'sound', 'quality'],
#  924: ['best', 'thing', 'invested', 'thank', '😁', '😁', '😁', '😁'],
#  925: ['extremely',
#   'impressed',
#   'item',
#   'bought',
#   '34;warehouse&#34',
#   '34;outlet&#34',
#   '34;minor',
#   'imperfection',
#   'tell',
#   'works',
#   'great',
#   'come',
#   'packaging',
#   'sealed',
#   'damage',
#   'missing',
#   'like',
#   'sound',
#   'quality',
#   'knock',
#   'bose',
#   'great',
#   'family',
#   'easy',
#   'use',
#   'minor',
#   'learning',
#   'curve',
#   'learns',
#   'voice',
#   'integrates',
#   'seamlessly',
#   'amazon',
#   'services',
#   "can't",
#   'wait',
#   'classroom',
#   'lot',
#   'fun',
#   'speaker',
#   'let',
#   'plan'],
#  926: ['love',
#   'echo',
#   'bedroom',
#   'wonderful',
#   'music',
#   'info',
#   'sleeping',
#   'sounds'],
#  927: ['awesome',
#   'life',
#   'changer',
#   'seriously',
#   'able',
#   'start',
#   'morning',
#   'alexa',
#   'having',
#   '34;wake&#34;me',
#   'alarm',
#   'playing',
#   'music',
#   'gotten',
#   'voice',
#   'room',
#   '34;listen&#34',
#   'love',
#   'echos',
#   'hesitate',
#   'price',
#   'speaker',
#   'unbelievable',
#   'buying',
#   'cordless',
#   'holder',
#   'echo',
#   'love',
#   'purchase',
#   'love',
#   'alexa'],
#  928: ['super',
#   'impressed',
#   'alexa',
#   'prime',
#   'lapsed',
#   'play',
#   'smart',
#   'differentiate',
#   'spotify',
#   'accounts',
#   'use',
#   'randomly',
#   'speaks',
#   'talking',
#   'today',
#   'unplugged',
#   '...',
#   'sure',
#   'use',
#   'alexa'],
#  929: ['like'],
#  930: ['liked', '100'],
#  931: ['issue',
#   'buying',
#   'use',
#   'electronics',
#   'long',
#   'good',
#   'like',
#   'new',
#   'read',
#   'comment'],
#  932: ['family', 'loves', 'new', 'echo'],
#  933: ['bought', 'wife', 'loves'],
#  934: ['fun', 'got', 'today', 'pod', 'car', 'use', 'house'],
#  935: ['like'],
#  936: ['echo',
#   'worth',
#   'penny',
#   'like',
#   'having',
#   '3',
#   'household',
#   'employees',
#   'small',
#   'flat',
#   'rate',
#   'bedrooms',
#   'living',
#   'room',
#   'drop',
#   'use',
#   'intercom',
#   'listen',
#   'music',
#   'answer',
#   'quick',
#   'questions',
#   'alarms',
#   'wake',
#   'school',
#   'etc'],
#  937: ['listen', 'music', 'set', 'timer'],
#  938: ['received',
#   'echo',
#   'perfect',
#   'condition',
#   'device',
#   'easy',
#   'set',
#   'responds',
#   'quickly',
#   'issues',
#   'alexa',
#   'great',
#   'addition',
#   'family'],
#  939: ['good',
#   'sound',
#   'like',
#   'music',
#   'scheduling',
#   'like',
#   'random',
#   'thoughts',
#   'recorded',
#   'think',
#   'jokes',
#   'cute'],
#  940: ['purchased',
#   'beginning',
#   'learn',
#   'far',
#   'pleased',
#   'amazed',
#   'different',
#   'actions',
#   'perform',
#   'enjoying',
#   'looking',
#   'forward',
#   'learning',
#   'options',
#   'provides'],
#  941: ['echo', 'great', 'smaller'],
#  942: ['funny',
#   'buy',
#   'looks',
#   'fun',
#   'winds',
#   'totally',
#   'useful',
#   'home',
#   'loving'],
#  943: ['bought',
#   'replace',
#   '34;dot&#34',
#   'living',
#   'room',
#   'speaker',
#   'slightly',
#   'better',
#   'hears',
#   'better',
#   'tv',
#   'unfortunately',
#   'understand',
#   'respond',
#   'requests',
#   'dot',
#   'frequently',
#   'request',
#   '2',
#   '3',
#   'times',
#   'want',
#   'dot',
#   'usually',
#   'exactly',
#   'want',
#   'request',
#   'consider',
#   'upgrade'],
#  944: ['good',
#   'experience',
#   'far',
#   'second',
#   'generation',
#   'echo',
#   'things',
#   'learn',
#   'time',
#   'right',
#   'enjoying',
#   'music',
#   'weather',
#   'updates',
#   'alarm',
#   'feature',
#   'personality',
#   'purchased',
#   'mini',
#   'smart',
#   'socket',
#   'yes',
#   'excited',
#   'begin'],
#  945: ['having',
#   'trouble',
#   'connecting',
#   'tv',
#   'exactly',
#   'tech',
#   'smart',
#   'sure',
#   'grandsons',
#   'figure',
#   'far',
#   'music'],
#  946: ['simply',
#   'love',
#   'echo',
#   'hardly',
#   'watch',
#   'tv',
#   'anymore',
#   'busy',
#   'listening',
#   'music',
#   'speaker',
#   'pretty',
#   'goo',
#   'size',
#   'fun',
#   'skills',
#   'echo',
#   'fun',
#   'family'],
#  947: ['enjoyed', 'entire', 'echo', 'experience'],
#  948: ['easy', 'set'],
#  949: ['echo',
#   'amazing',
#   'device',
#   'times',
#   'intuitive',
#   'times',
#   'ask',
#   'clear',
#   'simple',
#   'result',
#   'installation',
#   'fairly',
#   'straightforward',
#   'messed',
#   'times',
#   'simply',
#   'thought',
#   'step',
#   'complete',
#   'actually',
#   'lose',
#   'ground',
#   'figured',
#   'advice',
#   'patient',
#   'app',
#   'let',
#   'know',
#   'step',
#   'biggest',
#   'issue',
#   'moment',
#   'echo',
#   'devices',
#   'home',
#   'like',
#   'use',
#   'intercoms',
#   'told',
#   'echos',
#   'aware',
#   'existence',
#   'ask',
#   'alexa',
#   'answers',
#   'instructions',
#   'change',
#   'know',
#   'likely',
#   'fault',
#   'think',
#   'designers',
#   'anticipate',
#   'easier',
#   'find',
#   'needed',
#   'instructions',
#   'small',
#   'deal',
#   'device',
#   'savvy',
#   'people',
#   'challenge'],
#  950: ['loving'],
#  951: ['original',
#   'alexa',
#   'tap',
#   'far',
#   '2nd',
#   'generation',
#   'best',
#   'happy',
#   'making',
#   'improvements',
#   'new',
#   'great',
#   'updates',
#   'little',
#   'a.i.',
#   'think',
#   'help',
#   'lot',
#   'bugs',
#   'happy',
#   'play',
#   'music',
#   'house',
#   'adjust',
#   'bass',
#   'treble',
#   'thank'],
#  952: ['pleased',
#   'echo',
#   '2nd',
#   'generation',
#   'nice',
#   'alexa',
#   'available',
#   'music',
#   'weather',
#   'news',
#   'probably',
#   'lot',
#   'discovered'],
#  953: ['pleasantly',
#   'surprised',
#   'sound',
#   'quality',
#   'echo',
#   'big',
#   'fan',
#   'deep',
#   'bass',
#   'sufficient',
#   'potential',
#   'control',
#   'home',
#   'option',
#   'explore',
#   'evolve',
#   'home',
#   'smart',
#   'home',
#   'voice',
#   'recognition',
#   'impressive',
#   'stylish',
#   'fun',
#   'regrets',
#   'purchase',
#   'great',
#   'technically',
#   'changes',
#   'people',
#   'ask',
#   'play',
#   'song',
#   'movie',
#   'responds',
#   'instantly',
#   'elderly',
#   'loved',
#   'great',
#   'gift',
#   'connected',
#   'wifi',
#   'simple',
#   'use',
#   'want',
#   'unlimited',
#   'music',
#   'control',
#   'sure',
#   'amazon',
#   'prime',
#   'premium',
#   'spotify',
#   'blown',
#   'away',
#   'personal',
#   'dj',
#   'conversations',
#   'echo',
#   'embarrassed',
#   'echo',
#   'laugh',
#   'couple',
#   'times',
#   'ask',
#   'tell',
#   'joke',
#   'tells',
#   'packages',
#   'amazon',
#   'prime',
#   'addict',
#   'comes',
#   'extremely',
#   'handy'],
#  954: ['easy', 'setup', 'love', 'things'],
#  955: ['alexa', 'house----the', 'future', 'arrived'],
#  956: ['alexa',
#   'amazon',
#   'find',
#   'today',
#   'resist',
#   'getting',
#   'echo',
#   'best',
#   'thing',
#   'use',
#   'house',
#   'happier'],
#  957: ['arrived', 'expected'],
#  958: ['bought',
#   'weeks',
#   'ago',
#   'product',
#   'excellent',
#   'forget',
#   'buy',
#   'charger',
#   'ordering',
#   'outside',
#   'pool',
#   'worry',
#   'hiring',
#   'electrician',
#   'outlets',
#   'yard'],
#  959: ['terrific'],
#  960: ['love', 'echo'],
#  961: ['smaller', 'original', 'looks', 'nicer'],
#  962: ['works', 'great'],
#  963: ['husband',
#   '34;late',
#   'adopters&#34',
#   'come',
#   'technology',
#   'decide',
#   'try',
#   'echo',
#   'serve',
#   'primarily',
#   'music',
#   'source',
#   'wow',
#   'amazed',
#   'great',
#   'sound',
#   'having',
#   'great',
#   'time',
#   'listening',
#   'favorite',
#   'songs',
#   'buy',
#   'asking',
#   'alexa',
#   'buy',
#   'elderly',
#   'dad',
#   'think',
#   'enjoy',
#   'having',
#   'listen',
#   'music',
#   'place',
#   'calls'],
#  964: ['enjoyed',
#   'changing',
#   'directv',
#   'channels',
#   'plays',
#   'iheartradio',
#   'pandora',
#   'adjusts',
#   'ac',
#   'thermostat',
#   'turns',
#   'living',
#   'room',
#   'lights',
#   'outside',
#   'lights'],
#  965: ['wanting', 'bought', 'prime', 'day', 'absolutely', 'love'],
#  966: ['glad',
#   'got',
#   'echo',
#   'bluetooth',
#   'speaker',
#   'alexa',
#   'stuff',
#   'non',
#   'smart',
#   'speakers',
#   'personally',
#   'love',
#   'timer',
#   'feature',
#   'helped',
#   'cooking',
#   'multiple',
#   'things',
#   'simultaneously',
#   'pandora',
#   'integration',
#   'feature',
#   'use',
#   'daily',
#   'happy',
#   'prime',
#   'day',
#   'purchase',
#   'echo',
#   'hub',
#   'echo',
#   'dots',
#   'future'],
#  967: ['subject', 'line', 'love'],
#  968: ['love'],
#  969: ['easy', 'setup'],
#  970: ['hesitant',
#   'buy',
#   'echo',
#   'echo',
#   'dot',
#   'good',
#   'echo',
#   'sound',
#   'quality',
#   'feel',
#   'needed',
#   'glad',
#   'got',
#   'difference',
#   'sound',
#   'far',
#   'superior',
#   'echo',
#   'dot',
#   'listen',
#   'greatest',
#   'showman',
#   'little',
#   'power'],
#  971: ['sound', 'quality', 'great', 'learning', 'different', 'things', 'fun'],
#  972: ['got',
#   'good',
#   'deal',
#   'works',
#   'great',
#   'prime',
#   'setup',
#   'bit',
#   'pain',
#   'fault',
#   'crappy',
#   'internet',
#   'service',
#   'worked',
#   'great',
#   'nice',
#   'sound',
#   'small',
#   'speaker'],
#  973: ['love'],
#  974: ['works', 'great', 'perfect', 'office'],
#  975: ['love',
#   'it---',
#   'inside',
#   'house',
#   'pool',
#   'good',
#   'bose',
#   'speakers',
#   'house'],
#  976: ['easy', 'use', '--', 'amazing'],
#  977: ['nice', 'product', 'a+'],
#  978: ['love',
#   'echo',
#   'totally',
#   'amazed',
#   'speaker',
#   'quality',
#   'bummed',
#   'buy',
#   'got',
#   'prime',
#   'day'],
#  979: ['responsive', 'great', 'sound', 'quality', 'size'],
#  980: ['efficient', 'amazing', 'cool', 'use', 'day', '...'],
#  981: ['impressed',
#   'quality',
#   'sound',
#   'echo',
#   'definitely',
#   'comparable',
#   'bose',
#   'mini',
#   'gave',
#   '4',
#   'stars',
#   'use',
#   'apple',
#   'music',
#   'account'],
#  982: ['technology',
#   'small',
#   'device',
#   'price',
#   'good',
#   'sound',
#   'amazing',
#   'feature',
#   'home'],
#  983: ['mainly', 'use', 'music', 'learning', 'time', 'bad'],
#  984: ['replaced',
#   '1st',
#   'gen',
#   'concerned',
#   'smaller',
#   'unit',
#   'having',
#   'sound',
#   '...',
#   'wrong',
#   'volume',
#   'clear',
#   'good',
#   'product'],
#  985: ['great', 'addition', 'echo', 'plus'],
#  986: ['best'],
#  987: ['love', 'feature', 'play', 'music', 'room', 'multiple', 'echos'],
#  988: ['love', 'alexa', 'surprised', 'use'],
#  989: ['use', 'product', 'enjoyment', 'love'],
#  990: ['easy',
#   'use',
#   'great',
#   'sound',
#   '...',
#   'great',
#   'purchase',
#   'great',
#   'price'],
#  991: ['easy', 'set', 'issues'],
#  992: ['unit',
#   'add',
#   'pleasure',
#   'echo',
#   'plus',
#   'music',
#   'information',
#   'home',
#   'room'],
#  993: ['extremely',
#   'useful',
#   'simple',
#   'things',
#   'like',
#   'spotify',
#   'audible',
#   'things',
#   'like',
#   'answer',
#   'ask',
#   'nice',
#   'use'],
#  994: ['difficult', 'set', 'keeps', 'timing', 'enter', 'password'],
#  995: ['getting',
#   'use',
#   'echo',
#   'shopping',
#   'lists',
#   'listening',
#   'music',
#   'timer',
#   'working',
#   'great',
#   'far'],
#  996: ['cool', 'lots', 'fun', 'week', 'learning', 'capabilities'],
#  997: ['love', 'love'],
#  998: ['love', 'having', 'hard', 'time', 'setting', 'apps'],
#  999: ['use', 'office', 'apartment', 'music', 'information'],
#  ...}

# %% [markdown]
# ## After pre-processing, you can analyze the resulting data...
# ## Some Applications of NLP:
# - Sentiment Analysis
# - Document Similarity
# - Text analysis (e.g, common issues in reviews/surveys, frequently tweeted topics, etc.)

# %%
from negspacy.negation import Negex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-059e101030c2> in <module>
# ----> 1 from negspacy.negation import Negex
#
# ModuleNotFoundError: No module named 'negspacy'

# %%
pip install negspacy
# Out:
# Collecting negspacy
#   Downloading negspacy-0.1.8.tar.gz (9.8 kB)
# Requirement already satisfied: spacy>=2.1.8 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from negspacy) (2.3.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (0.9.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (1.0.2)
# Requirement already satisfied: thinc==7.4.1 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (7.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (1.18.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (4.46.0)
# Requirement already satisfied: setuptools in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (46.1.3.post20200330)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (2.0.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (0.8.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (3.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.8->negspacy) (0.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.8->negspacy) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.8->negspacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.8->negspacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.8->negspacy) (1.25.8)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.1.8->negspacy) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /Users/ezhang/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.1.8->negspacy) (3.1.0)
# Building wheels for collected packages: negspacy
#   Building wheel for negspacy (setup.py) ... done
#   Created wheel for negspacy: filename=negspacy-0.1.8-py3-none-any.whl size=8842 sha256=59a23bcb52f96dbefc1c53d1a8ce3da51a1d22b21129d2afc1846c53630e5d1b
#   Stored in directory: /Users/ezhang/Library/Caches/pip/wheels/a9/ef/52/d5274e443e446f41084fb7436bffe4f78b36a5bf637c5e4bd4
# Successfully built negspacy
# Installing collected packages: negspacy
# Successfully installed negspacy-0.1.8
# Note: you may need to restart the kernel to use updated packages.
